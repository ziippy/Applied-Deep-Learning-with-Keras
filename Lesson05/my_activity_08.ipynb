# %%
import numpy as np
data = np.loadtxt("./data/pima-indians-diabetes.csv", delimiter=",")
X = data[:,0:8]
y = data[:, 8]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
import numpy as np
np.random.seed(1)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential()
model.add(Dense(8, activation='relu', input_dim=8))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
history=model.fit(X_train, y_train, batch_size = 10, epochs = 300, validation_data=(X_test, y_test))
# Out:
# Train on 537 samples, validate on 231 samples
# Epoch 1/300
# 537/537 [==============================] - 0s 463us/step - loss: 2.0013 - acc: 0.5177 - val_loss: 0.6737 - val_acc: 0.6840
# Epoch 2/300
# 537/537 [==============================] - 0s 196us/step - loss: 0.7011 - acc: 0.6294 - val_loss: 0.6822 - val_acc: 0.6797
# Epoch 3/300
# 537/537 [==============================] - 0s 710us/step - loss: 0.6808 - acc: 0.6406 - val_loss: 0.6658 - val_acc: 0.6840
# Epoch 4/300
# 537/537 [==============================] - 0s 701us/step - loss: 0.6694 - acc: 0.6369 - val_loss: 0.6537 - val_acc: 0.6840
# Epoch 5/300
# 537/537 [==============================] - 0s 677us/step - loss: 0.6545 - acc: 0.6406 - val_loss: 0.6298 - val_acc: 0.6797
# Epoch 6/300
# 537/537 [==============================] - 0s 659us/step - loss: 0.6584 - acc: 0.6425 - val_loss: 0.6279 - val_acc: 0.6883
# Epoch 7/300
# ...

# %%
import matplotlib.pyplot as plt 
import matplotlib
# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0) 

# plot training error and test error plots 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylim(0,1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test loss'], loc='upper right')

# print the best accuracy reached on training set and the test set
print("Best Accuracy on training set = ", max(history.history['acc'])*100)
print("Best Accuracy on test set = ", max(history.history['val_acc'])*100)
# Out:
# Best Accuracy on training set =  65.36312883570652
# Best Accuracy on test set =  68.83116939883212

# %%
from keras.regularizers import l2

model2 = Sequential()
model2.add(Dense(8, activation='relu', input_dim=8, kernel_regularizer=l2(0.01)))
model2.add(Dense(8, activation='relu', kernel_regularizer=l2(0.01)))
model2.add(Dense(1, activation='sigmoid'))
model2.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
history2=model2.fit(X_train, y_train, batch_size = 10, epochs = 300, validation_data=(X_test, y_test), verbose=0)

# %%
# plot training error and test error plots 
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.ylim(0,1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test loss'], loc='upper right')

# print the best accuracy reached on training set and the test set
print("Best Accuracy on training set = ", max(history2.history['acc'])*100)
print("Best Accuracy on test set = ", max(history2.history['val_acc'])*100)
# Out:
# Best Accuracy on training set =  72.06703934478583
# Best Accuracy on test set =  73.16017243769262

# %%
model3 = Sequential()
model3.add(Dense(8, activation='relu', input_dim=8, kernel_regularizer=l2(0.1)))
model3.add(Dense(8, activation='relu', kernel_regularizer=l2(0.1)))
model3.add(Dense(1, activation='sigmoid'))
model3.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
history3=model3.fit(X_train, y_train, batch_size = 10, epochs = 300, validation_data=(X_test, y_test), verbose=0)

# plot training error and test error plots 
plt.plot(history3.history['loss'])
plt.plot(history3.history['val_loss'])
plt.ylim(0,1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test loss'], loc='upper right')

# print the best accuracy reached on training set and the test set
print("Best Accuracy on training set = ", max(history3.history['acc'])*100)
print("Best Accuracy on test set = ", max(history3.history['val_acc'])*100)
# Out:
# Best Accuracy on training set =  73.37057714799707
# Best Accuracy on test set =  76.19047631949057

# %%
model4 = Sequential()
model4.add(Dense(8, activation='relu', input_dim=8, kernel_regularizer=l2(0.5)))
model4.add(Dense(8, activation='relu', kernel_regularizer=l2(0.5)))
model4.add(Dense(1, activation='sigmoid'))
model4.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
history4=model4.fit(X_train, y_train, batch_size = 10, epochs = 300, validation_data=(X_test, y_test), verbose=0)

# plot training error and test error plots 
plt.plot(history4.history['loss'])
plt.plot(history4.history['val_loss'])
plt.ylim(0,1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test loss'], loc='upper right')

# print the best accuracy reached on training set and the test set
print("Best Accuracy on training set = ", max(history4.history['acc'])*100)
print("Best Accuracy on test set = ", max(history4.history['val_acc'])*100)
# Out:
# Best Accuracy on training set =  70.57728122510501
# Best Accuracy on test set =  75.32467511825232

# %%
from keras.regularizers import l1

model5 = Sequential()
model5.add(Dense(8, activation='relu', input_dim=8, kernel_regularizer=l1(0.01)))
model5.add(Dense(8, activation='relu', kernel_regularizer=l1(0.01)))
model5.add(Dense(1, activation='sigmoid'))
model5.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
history5=model5.fit(X_train, y_train, batch_size = 10, epochs = 300, validation_data=(X_test, y_test), verbose=0)

# plot training error and test error plots 
plt.plot(history5.history['loss'])
plt.plot(history5.history['val_loss'])
plt.ylim(0,1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test loss'], loc='upper right')

# print the best accuracy reached on training set and the test set
print("Best Accuracy on training set = ", max(history5.history['acc'])*100)
print("Best Accuracy on test set = ", max(history5.history['val_acc'])*100)
# Out:
# Best Accuracy on training set =  73.7430168263739
# Best Accuracy on test set =  77.48917754078323

# %%
model6 = Sequential()
model6.add(Dense(8, activation='relu', input_dim=8, kernel_regularizer=l1(0.1)))
model6.add(Dense(8, activation='relu', kernel_regularizer=l1(0.1)))
model6.add(Dense(1, activation='sigmoid'))
model6.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
history6=model6.fit(X_train, y_train, batch_size = 10, epochs = 300, validation_data=(X_test, y_test), verbose=0)

# plot training error and test error plots 
plt.plot(history6.history['loss'])
plt.plot(history6.history['val_loss'])
plt.ylim(0,1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test loss'], loc='upper right')

# print the best accuracy reached on training set and the test set
print("Best Accuracy on training set = ", max(history6.history['acc'])*100)
print("Best Accuracy on test set = ", max(history6.history['val_acc'])*100)
# Out:
# Best Accuracy on training set =  65.17690907976481
# Best Accuracy on test set =  67.96536845562262

# %%
from keras.regularizers import l1_l2

model7 = Sequential()
model7.add(Dense(8, activation='relu', input_dim=8, kernel_regularizer=l1_l2(l1=0.01, l2=0.1)))
model7.add(Dense(8, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.1)))
model7.add(Dense(1, activation='sigmoid'))
model7.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
history7=model7.fit(X_train, y_train, batch_size = 10, epochs = 300, validation_data=(X_test, y_test), verbose=0)

# plot training error and test error plots 
plt.plot(history7.history['loss'])
plt.plot(history7.history['val_loss'])
plt.ylim(0,1)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'test loss'], loc='upper right')

# print the best accuracy reached on training set and the test set
print("Best Accuracy on training set = ", max(history7.history['acc'])*100)
print("Best Accuracy on test set = ", max(history7.history['val_acc'])*100)
# Out:
# Best Accuracy on training set =  73.55679709818111
# Best Accuracy on test set =  77.48917728275447
