# %%
# ResNet50 모델 미세 튜닝
# 망을 동결하고, 1000개의 라벨을 가진 마지막 레이어를 제거
import numpy as np
import keras
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import GlobalAveragePooling2D
from keras.models import Model

resnet50 = keras.applications.resnet50.ResNet50(include_top=False)
x = resnet50.output
x = GlobalAveragePooling2D()(x)
#x = Dense(1, activation='sigmoid')(x)
#x = Dense(128, activation='relu')(x)
x = Dense(2, activation='softmax')(x)
model = Model(inputs=resnet50.input, outputs=x)
#
# 레이어 동결
for layer in resnet50.layers:
    layer.trainable=False
#
model.summary()
# Out:
# WARNING:tensorflow:From /home/ziippy/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/ziippy/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/ziippy/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /home/ziippy/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /home/ziippy/venv/lib/python3.6/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/ziippy/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/ziippy/venv/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# 이미지를 처리하고, ANN 피팅 진행
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.resnet50 import preprocess_input
from keras.callbacks import ModelCheckpoint

#train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True, preprocessing_function=preprocess_input)
#test_datagen = ImageDataGenerator(rescale=1./255, preprocessing_function=preprocess_input)
train_datagen = ImageDataGenerator(shear_range=0.2, zoom_range=0.2, horizontal_flip=True, preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

training_set = train_datagen.flow_from_directory('Data/Dataset/training_set', target_size=(224,224), batch_size=32, class_mode='categorical')
test_set = test_datagen.flow_from_directory('Data/Dataset/test_set', target_size=(224,224), batch_size=32, class_mode='categorical', shuffle=False)

history = model.fit_generator(training_set, steps_per_epoch=100, epochs=10, validation_data=test_set, validation_steps=30,
                             callbacks=[
                                 ModelCheckpoint('model.h5', monitor='val_acc', save_best_only=True, verbose=1)
                             ])
# Out:
# Found 200 images belonging to 2 classes.
# Found 115 images belonging to 2 classes.
# WARNING:tensorflow:From /home/ziippy/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/ziippy/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/10
# 100/100 [==============================] - 23s 230ms/step - loss: 0.1749 - acc: 0.9266 - val_loss: 0.0169 - val_acc: 1.0000
#
# Epoch 00001: val_acc improved from -inf to 1.00000, saving model to model.h5
# Epoch 2/10
# 100/100 [==============================] - 20s 202ms/step - loss: 0.0434 - acc: 0.9900 - val_loss: 0.0161 - val_acc: 1.0000
#
# Epoch 00002: val_acc did not improve from 1.00000
# Epoch 3/10
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline 
#matplotlib.rcParams['figure.figsize'] = (10.0, 8.0) 

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylim(0,0.2)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'val loss'], loc='upper right')

# %%
training_set.class_indices
# Out:
# {'cats': 0, 'dogs': 1}

# %%
from keras.preprocessing import image
import numpy as np

new_image = image.load_img('Data/Prediction/test_image_6.jpg', target_size=(224,224))
plt.imshow(new_image)
new_image = image.img_to_array(new_image)
new_image = np.expand_dims(new_image, axis=0)
#new_image = preprocess_input(new_image)

result = model.predict(new_image)
print(result[0][0], ' ', result[0][1])
# Out:
# 2.8668952e-05   0.9999714

# %%
new_image = image.load_img('Data/Prediction/test_image_4.jpg', target_size=(224,224))
plt.imshow(new_image)
new_image = image.img_to_array(new_image)
new_image = np.expand_dims(new_image, axis=0)
#new_image = preprocess_input(new_image)

result = model.predict(new_image)
print(result[0][0], ' ', result[0][1])
# Out:
# 9.88471e-07   0.99999905

# %%
new_image = image.load_img('Data/Prediction/test_image_1.jpg', target_size=(224,224))
plt.imshow(new_image)
new_image = image.img_to_array(new_image)
new_image = np.expand_dims(new_image, axis=0)
#new_image = preprocess_input(new_image)

result = model.predict(new_image)
print(result[0][0], ' ', result[0][1])
# Out:
# 1.0   5.930362e-10

# %%
from keras.models import load_model
model2 = load_model('model.h5')

# %%
last_weight = model2.layers[-1].get_weights()[0]
last_weight
# Out:
# array([[-0.02395496,  0.01595616],
#        [ 0.02625648, -0.05202132],
#        [-0.0262593 , -0.02020258],
#        ...,
#        [ 0.00437877, -0.00421668],
#        [ 0.04797361, -0.01275827],
#        [ 0.00561948,  0.05477054]], dtype=float32)

# %%
new_model = Model(inputs=model2.input,
                 outputs=(
                     model2.layers[-3].output,  # the layer just before GAP, for using spartial features
                     model2.layers[-1].output
                 ))

# %%
new_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# ...

# %%
new_image = image.load_img('Data/Prediction/test_image_1.jpg', target_size=(224,224))
plt.imshow(new_image)
new_image = image.img_to_array(new_image)
new_image = np.expand_dims(new_image, axis=0)
#new_image = preprocess_input(new_image)

result = model2.predict(new_image)
print(result[0][0], ' ', result[0][1])
# Out:
# 0.9999684   3.159765e-05

# %%
new_image = image.load_img('Data/Prediction/test_image_6.jpg', target_size=(224,224))
plt.imshow(new_image)
new_image2 = image.img_to_array(new_image)
new_image2 = np.expand_dims(new_image2, axis=0)
#new_image = preprocess_input(new_image)

last_conv_output, result = new_model.predict(new_image2)
print(result[0][0], ' ', result[0][1])
# Out:
# 0.00013939674   0.9998605

# %%
import scipy

last_conv_output = np.squeeze(last_conv_output)          # (7, 7, 2048)
#print(last_conv_output.shape)
feature_activation_maps = scipy.ndimage.zoom(last_conv_output, (32, 32, 1), order=1) # (7, 7, 2048) -> (224, 224, 2048)
#print(feature_activation_maps.shape)

pred_class = np.argmax(result)
predicted_class_weights = last_weight[:, pred_class] # (2048,1)
#print(predicted_class_weights.shape)

# (224*224, 2048) dot_produt (2048,1) = (224*224, 1)
final_output = np.dot(feature_activation_maps.reshape((224*224, 2048)), predicted_class_weights).reshape((224, 224))

plt.imshow(final_output, cmap='jet')

# %%
plt.imshow(new_image, alpha=0.5)
plt.imshow(final_output, cmap='jet', alpha=0.5)
